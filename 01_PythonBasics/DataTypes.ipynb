# %%
#int data type
age=10
print(age)
print(type(age))
# Out:
# 10
# <class 'int'>

# %%
#String Data type
name="Shyam"
print(name)
print(type(name))
# Out:
# Shyam
# <class 'str'>

# %%
#bool data type
eligible=True
print(eligible)
print(type(eligible))
# Out:
# True
# <class 'bool'>

# %%
#common error 
msg="Hello"*5
print(msg)
# Out:
# HelloHelloHelloHelloHello

# %%
#if we have to get rid of the the above error we need to typecast 
msg="Hello"+ str(5)
print(msg)
# Out:
# Hello5
